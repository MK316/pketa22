# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/pketa22/blob/main/Demo_phonetics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Phonetic transcription
#
# - Creating sounds of English words

# %%
#@markdown 🚩 {gTTS} package installation and import
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

# %%
#@markdown 🐬 Choose language & dialect:

def tts(mytext):
  text_to_say = mytext
  language_to_choose = "en" #@param ["en", "ko", "fr", 'es']
  language = language_to_choose

  sp = "0" #@param [0, 1]
  sp = int(sp)
  speed = bool(sp)

  dialect = "com" #@param ["com","co.uk","com.au","ca","co.in","ie"]
  print("Play language accent: %s"%language_to_choose)
  print("Play local accent: %s"%dialect)
  language = language_to_choose

  gtts_object = gTTS(text = text_to_say,
                     lang = language, tld = dialect,
                    slow = speed)  
  gtts_object.save("mytext.wav")
  return Audio("mytext.wav")

# text_to_say = text

# intro_text = "I'll repeat a word three times. "
# text_to_say = intro_text + text_to_say 

# tts(text_to_say)

# %%
#@markdown 😍 Hello to students:
text = """
Hello students in the Phonetics class of Fall 2022! Very nice to meet you!  Today? we'll be practicing sound transcription. I'll be saying each word three times. While listening? first, give phonetic transcription, second, write the spelling, and finally?, provide its phonemic transcription. This order is an easer way that I recommend. But if you don't like my suggestion, just do as you want to do! If you have any question before we proceed, ask professor Miran Kim now!  
"""
tts(text)
# Out:
# Play language accent: en
# Play local accent: com
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown 🐬 Choose language & dialect:

def tts(mytext):
  text_to_say = mytext
  language_to_choose = "en" #@param ["en", "ko", "fr", 'es']
  language = language_to_choose

  sp = "1" #@param [0, 1]
  sp = int(sp)
  speed = bool(sp)

  dialect = "com" #@param ["com","co.uk","com.au","ca","co.in","ie"]
  print("Play language accent: %s"%language_to_choose)
  print("Play local accent: %s"%dialect)
  language = language_to_choose

  gtts_object = gTTS(text = text_to_say,
                     lang = language, tld = dialect,
                    slow = speed)  
  gtts_object.save("mytext.wav")
  return Audio("mytext.wav")

# text_to_say = text

# intro_text = "I'll repeat a word three times. "
# text_to_say = intro_text + text_to_say 

# tts(text_to_say)

# %%
#@markdown Wordlist
import pandas as pd

url = "https://raw.githubusercontent.com/MK316/Fall2022/main/F22Testwords.csv"
df = pd.read_csv(url)

w = "1" #@param [1, 2, 3, 4, 5, 6, 7, 8]
wn = int(w)-1
w1 = df['Words'][wn]
w2 = str(w)

intro = "Number %s. "%w2
text_to_say = intro + w1
tts(text_to_say)
# Out:
# Play language accent: en
# Play local accent: co.uk
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts(w1)
# Out:
# Play language accent: en
# Play local accent: com
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = True;
b = True;
match_var = True if a == b else False
type(match_var)
type(bool(0))
# Out:
# bool
